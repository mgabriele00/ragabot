# %% [markdown]
# ## Data Preparation

# %%
import numpy as np
import polars as pl
import talib
import pandas as pd
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report, confusion_matrix, precision_recall_curve, make_scorer, f1_score
)
from sklearn.utils import resample
from xgboost import XGBClassifier
import joblib
import matplotlib.pyplot as plt
import optuna
from numba import njit

# %%
# Carica dati CSV con Polars
def load_data(csv_path):
    df = pl.read_csv(csv_path)
    df = df.with_columns(
        (pl.col('Date') + ' ' + pl.col('Time')).alias('datetime')
    ).drop(['Date', 'Time'])
    df = df.with_columns(pl.col('datetime').str.to_datetime('%Y.%m.%d %H:%M'))
    df = df.set_sorted('datetime')
    return df

# %%
import numpy as np
import polars as pl
import talib

# Carica dati CSV con Polars
def load_data(csv_path):
    df = pl.read_csv(csv_path)
    df = df.with_columns(
        (pl.col('Date') + ' ' + pl.col('Time')).alias('datetime')
    ).drop(['Date', 'Time'])
    df = df.with_columns(pl.col('datetime').str.to_datetime('%Y.%m.%d %H:%M'))
    df = df.set_sorted('datetime')
    return df

@njit(fastmath=True)
def simulate_close_numba(current_price, sigma, n_sim=10000, dt=1.0, mu=0.0):
    Z = np.random.randn(n_sim)
    log_ret = (mu - 0.5 * sigma ** 2) * dt + sigma * np.sqrt(dt) * Z
    return current_price * np.exp(log_ret)

# Calcolo feature tecniche + variabili storiche
def calculate_features(df, history_bars=5):
    close = df['Close'].to_numpy()
    high = df['High'].to_numpy()
    low = df['Low'].to_numpy()
    open_ = df['Open'].to_numpy()

    features = {
        'ATR': talib.ATR(high, low, close, timeperiod=14),
        'RSI': talib.RSI(close, timeperiod=14),
    }


    log_ret = np.log(close / np.roll(close, 1))
    log_ret[0] = 0
    sigma = pd.Series(log_ret).rolling(window=100).std().to_numpy()
    features["sigma"] = sigma

    
    mc_mean = []
    mc_std = []
    mc_max = []
    mc_min = []
    mc_prob_up = []
    
    for i in range(len(close)):
        if np.isnan(close[i]) or np.isnan(sigma[i]):
          mc_mean.append(np.nan)
          mc_std.append(np.nan)
          mc_max.append(np.nan)
          mc_min.append(np.nan)
          mc_prob_up.append(np.nan)
        continue

    sims = simulate_close_numba(close[i], sigma[i], n_sim=1000)

    mc_mean.append(sims.mean())
    mc_std.append(sims.std())
    mc_max.append(sims.max())
    mc_min.append(sims.min())
    mc_prob_up.append(np.mean(sims > close[i]))

    features.update({
        "MC_mean": mc_mean,
        "MC_std": mc_std,
        "MC_max": mc_max,
        "MC_min": mc_min,
       "MC_prob_up": mc_prob_up
    })
    
    upper, mid, lower = talib.BBANDS(close, timeperiod=14, nbdevup=2, nbdevdn=2)
    features.update({
        'BB_upper': upper,
        'BB_mid': mid,
        'BB_lower': lower,
        'SMA_10': talib.SMA(close, 10),
        'SMA_20': talib.SMA(close, 20),
        'EMA_10': talib.EMA(close, 10),
        'EMA_20': talib.EMA(close, 20),
    })

    macd, macdsignal, macdhist = talib.MACD(close, 12, 26, 9)
    features.update({
        'MACD': macd,
        'MACD_signal': macdsignal,
        'MACD_hist': macdhist,
    })

    # Supertrend personalizzato
    def supertrend(high, low, close, period=10, multiplier=3):
        atr = talib.ATR(high, low, close, period)
        hl2 = (high + low) / 2
        upperband = hl2 + (multiplier * atr)
        lowerband = hl2 - (multiplier * atr)

        trend = np.zeros(len(close))
        direction = 1

        for i in range(1, len(close)):
            if close[i] > upperband[i - 1]:
                direction = 1
            elif close[i] < lowerband[i - 1]:
                direction = -1
            trend[i] = upperband[i] if direction == -1 else lowerband[i]
        return trend

    features['Supertrend'] = supertrend(high, low, close)

    # Pattern candlestick TA-Lib
    patterns = talib.get_function_groups()["Pattern Recognition"]
    for pattern in patterns:
        func = getattr(talib, pattern)
        features[pattern] = np.sign(func(open_, high, low, close))

    features_df = pl.DataFrame(features)

    # Shift delle feature e dei prezzi grezzi
    all_shifts = []
    for i in range(1, history_bars + 1):
        shifted_features = features_df.select([pl.col(c).shift(i) for c in features_df.columns])
        shifted_features = shifted_features.rename({col: f"{col}_t{i}" for col in shifted_features.columns})
        all_shifts.append(shifted_features)

    # Shift anche di Close, High, Low
    for price_col in ['Close', 'High', 'Low']:
        for i in range(1, history_bars + 1):
            df = df.with_columns(pl.col(price_col).shift(i).alias(f"{price_col}_t{i}"))

    all_shifted = pl.concat(all_shifts, how="horizontal")
    return df.hstack(features_df).hstack(all_shifted)

# Calcola livelli teorici TP e SL
def calculate_tp_sl(df, features, tp_mult=8, sl_mult=1):
    close = df['Close'].to_numpy()
    atr = features['ATR'].to_numpy()

    tp = close + tp_mult * atr
    sl = close - sl_mult * atr

    features = features.with_columns([
        pl.Series('TP_theoretical', tp),
        pl.Series('SL_theoretical', sl)
    ])
    return features


def create_feature_dataset(csv_path, max_rows=1000):
    df = load_data(csv_path)

    # ✅ Limita a max_rows righe dopo ordinamento
    df = df.head(max_rows)

    df_with_features = calculate_features(df)
    df_with_tp_sl = calculate_tp_sl(df_with_features, df_with_features)

    final_df = df_with_tp_sl.drop_nulls()
    return final_df

# %%
# Esecuzione
if __name__ == "__main__":
    csv_path = '../close_pred/data/EURUSD_M1_2013_2024.csv'
    feature_dataset = create_feature_dataset(csv_path, max_rows=1000)
    feature_dataset.write_parquet('feature_dataset.parquet')
    print("✅ Dataset con feature tecniche, storiche e livelli TP/SL (max 1000 righe) salvato correttamente.")
# Out:
# ---------------------------------------------------------------------------
# ShapeError                                Traceback (most recent call last)
# Cell In[63], line 4
#       2 if __name__ == "__main__":
#       3     csv_path = '../close_pred/data/EURUSD_M1_2013_2024.csv'
# ----> 4     feature_dataset = create_feature_dataset(csv_path, max_rows=1000)
#       5     feature_dataset.write_parquet('feature_dataset.parquet')
#       6     print("✅ Dataset con feature tecniche, storiche e livelli TP/SL (max 1000 righe) salvato correttamente.")
#
# Cell In[62], line 153, in create_feature_dataset(csv_path, max_rows)
#     150 # ✅ Limita a max_rows righe dopo ordinamento
#     151 df = df.head(max_rows)
# --> 153 df_with_features = calculate_features(df)
#     154 df_with_tp_sl = calculate_tp_sl(df_with_features, df_with_features)
#     156 final_df = df_with_tp_sl.drop_nulls()
#
# Cell In[62], line 115, in calculate_features(df, history_bars)
#     112     func = getattr(talib, pattern)
#     113     features[pattern] = np.sign(func(open_, high, low, close))
# --> 115 features_df = pl.DataFrame(features)
#     117 # Shift delle feature e dei prezzi grezzi
#     118 all_shifts = []
#
# File /opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py:358, in DataFrame.__init__(self, data, schema, schema_overrides, strict, orient, infer_schema_length, nan_to_null)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=352'>353</a>     self._df = dict_to_pydf(
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=353'>354</a>         {}, schema=schema, schema_overrides=schema_overrides
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=354'>355</a>     )
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=356'>357</a> elif isinstance(data, dict):
# --> <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=357'>358</a>     self._df = dict_to_pydf(
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=358'>359</a>         data,
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=359'>360</a>         schema=schema,
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=360'>361</a>         schema_overrides=schema_overrides,
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=361'>362</a>         strict=strict,
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=362'>363</a>         nan_to_null=nan_to_null,
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=363'>364</a>     )
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=365'>366</a> elif isinstance(data, (list, tuple, Sequence)):
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=366'>367</a>     self._df = sequence_to_pydf(
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=367'>368</a>         data,
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=368'>369</a>         schema=schema,
#    (...)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=373'>374</a>         nan_to_null=nan_to_null,
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/dataframe/frame.py?line=374'>375</a>     )
#
# File /opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/_utils/construction/dataframe.py:168, in dict_to_pydf(data, schema, schema_overrides, strict, nan_to_null, allow_multithreaded)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/_utils/construction/dataframe.py?line=156'>157</a>     data_series = [
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/_utils/construction/dataframe.py?line=157'>158</a>         s._s
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/_utils/construction/dataframe.py?line=158'>159</a>         for s in _expand_dict_values(
#    (...)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/_utils/construction/dataframe.py?line=163'>164</a>         ).values()
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/_utils/construction/dataframe.py?line=164'>165</a>     ]
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/_utils/construction/dataframe.py?line=166'>167</a> data_series = _handle_columns_arg(data_series, columns=column_names, from_dict=True)
# --> <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/_utils/construction/dataframe.py?line=167'>168</a> pydf = PyDataFrame(data_series)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/_utils/construction/dataframe.py?line=169'>170</a> if schema_overrides and pydf.dtypes() != list(schema_overrides.values()):
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/_utils/construction/dataframe.py?line=170'>171</a>     pydf = _post_apply_columns(
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/_utils/construction/dataframe.py?line=171'>172</a>         pydf, column_names, schema_overrides=schema_overrides, strict=strict
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/polars/_utils/construction/dataframe.py?line=172'>173</a>     )
#
# ShapeError: could not create a new DataFrame: height of column 'MC_mean' (100) does not match height of column 'ATR' (1000)

# %%
import polars as pl

def explode_polars(
    input_parquet: str,
    output_parquet: str,
    n_bars: int = 10
) -> None:
    """
    Per ogni riga (barra) del dataset di input:
    - Replica le successive n_bars righe come "barre future"
    - Mantieni i livelli TP_theoretical e SL_theoretical della riga base
    - Calcola target:
        +1 se close_{t+offset+1} >= TP_theoretical
        -1 se close_{t+offset+1} <= SL_theoretical
         0 altrimenti
    """
    df = pl.read_parquet(input_parquet)
    required = {"TP_theoretical", "SL_theoretical", "Close"}
    missing = required - set(df.columns)
    if missing:
        raise ValueError(f"Mancano colonne: {missing}")

    df = df.with_row_index("base_idx")

    df_base = df
    df_future = df.rename({"base_idx": "future_idx", "Close": "future_close"})

    offsets = pl.DataFrame({"offset": list(range(1, n_bars + 1))})

    expl = df_base.join(offsets, how="cross")
    expl = expl.with_columns((pl.col("base_idx") + pl.col("offset")).alias("future_idx"))

    # ✅ shift di +1 sul future_idx per ottenere close_{t+offset+1}
    expl = expl.with_columns((pl.col("future_idx") + 1).alias("target_idx"))

    # join con close della riga successiva
    expl = expl.join(df.select(["base_idx", "Close"]).rename({
        "base_idx": "target_idx",
        "Close": "target_close"
    }), on="target_idx", how="left")

    # ✅ target calcolata su close_{t+offset+1}
    expl = expl.with_columns(
        pl.when(pl.col("target_close") >= pl.col("TP_theoretical")).then(1)
          .when(pl.col("target_close") <= pl.col("SL_theoretical")).then(-1)
          .otherwise(0).alias("target")
    )

    expl = expl.drop_nulls()
    expl.write_parquet(output_parquet)
    print(f"✅ Dataset esploso salvato in: {output_parquet}")

if __name__ == '__main__':
    explode_polars('feature_dataset.parquet','exploded_dataset.parquet',n_bars=10)
# Out:
# ✅ Dataset esploso salvato in: exploded_dataset.parquet

# %%
# 1. Carica e pulisci dataset
df = pd.read_parquet('../close_pred/exploded_dataset.parquet')
df = df.dropna()
print(f"Righe totali: {len(df)}")
df.columns.tolist()
# Out:
# Righe totali: 9555
# ['base_idx',
#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'Volume',
#  'datetime',
#  'Close_t1',
#  'Close_t2',
#  'Close_t3',
#  'Close_t4',
#  'Close_t5',
#  'High_t1',
#  'High_t2',
#  'High_t3',
#  'High_t4',
#  'High_t5',
#  'Low_t1',
#  'Low_t2',
#  'Low_t3',
#  'Low_t4',
#  'Low_t5',
#  'ATR',
#  'RSI',
#  'BB_upper',
#  'BB_mid',
#  'BB_lower',
#  'SMA_10',
#  'SMA_20',
#  'EMA_10',
#  'EMA_20',
#  'MACD',
#  'MACD_signal',
#  'MACD_hist',
#  'Supertrend',
#  'CDL2CROWS',
#  'CDL3BLACKCROWS',
#  'CDL3INSIDE',
#  'CDL3LINESTRIKE',
#  'CDL3OUTSIDE',
#  'CDL3STARSINSOUTH',
#  'CDL3WHITESOLDIERS',
#  'CDLABANDONEDBABY',
#  'CDLADVANCEBLOCK',
#  'CDLBELTHOLD',
#  'CDLBREAKAWAY',
#  'CDLCLOSINGMARUBOZU',
#  'CDLCONCEALBABYSWALL',
#  'CDLCOUNTERATTACK',
#  'CDLDARKCLOUDCOVER',
#  'CDLDOJI',
#  'CDLDOJISTAR',
#  'CDLDRAGONFLYDOJI',
#  'CDLENGULFING',
#  'CDLEVENINGDOJISTAR',
#  'CDLEVENINGSTAR',
#  'CDLGAPSIDESIDEWHITE',
#  'CDLGRAVESTONEDOJI',
#  'CDLHAMMER',
#  'CDLHANGINGMAN',
#  'CDLHARAMI',
#  'CDLHARAMICROSS',
#  'CDLHIGHWAVE',
#  'CDLHIKKAKE',
#  'CDLHIKKAKEMOD',
#  'CDLHOMINGPIGEON',
#  'CDLIDENTICAL3CROWS',
#  'CDLINNECK',
#  'CDLINVERTEDHAMMER',
#  'CDLKICKING',
#  'CDLKICKINGBYLENGTH',
#  'CDLLADDERBOTTOM',
#  'CDLLONGLEGGEDDOJI',
#  'CDLLONGLINE',
#  'CDLMARUBOZU',
#  'CDLMATCHINGLOW',
#  'CDLMATHOLD',
#  'CDLMORNINGDOJISTAR',
#  'CDLMORNINGSTAR',
#  'CDLONNECK',
#  'CDLPIERCING',
#  'CDLRICKSHAWMAN',
#  'CDLRISEFALL3METHODS',
#  'CDLSEPARATINGLINES',
#  'CDLSHOOTINGSTAR',
#  'CDLSHORTLINE',
#  'CDLSPINNINGTOP',
#  'CDLSTALLEDPATTERN',
#  'CDLSTICKSANDWICH',
#  'CDLTAKURI',
#  'CDLTASUKIGAP',
#  'CDLTHRUSTING',
#  'CDLTRISTAR',
#  'CDLUNIQUE3RIVER',
#  'CDLUPSIDEGAP2CROWS',
#  'CDLXSIDEGAP3METHODS',
#  'ATR_t1',
#  'RSI_t1',
#  'BB_upper_t1',
#  'BB_mid_t1',
#  'BB_lower_t1',
#  'SMA_10_t1',
#  'SMA_20_t1',
#  'EMA_10_t1',
#  'EMA_20_t1',
#  'MACD_t1',
#  'MACD_signal_t1',
#  'MACD_hist_t1',
#  'Supertrend_t1',
#  'CDL2CROWS_t1',
#  'CDL3BLACKCROWS_t1',
#  'CDL3INSIDE_t1',
#  'CDL3LINESTRIKE_t1',
#  'CDL3OUTSIDE_t1',
#  'CDL3STARSINSOUTH_t1',
#  'CDL3WHITESOLDIERS_t1',
#  'CDLABANDONEDBABY_t1',
#  'CDLADVANCEBLOCK_t1',
#  'CDLBELTHOLD_t1',
#  'CDLBREAKAWAY_t1',
#  'CDLCLOSINGMARUBOZU_t1',
#  'CDLCONCEALBABYSWALL_t1',
#  'CDLCOUNTERATTACK_t1',
#  'CDLDARKCLOUDCOVER_t1',
#  'CDLDOJI_t1',
#  'CDLDOJISTAR_t1',
#  'CDLDRAGONFLYDOJI_t1',
#  'CDLENGULFING_t1',
#  'CDLEVENINGDOJISTAR_t1',
#  'CDLEVENINGSTAR_t1',
#  'CDLGAPSIDESIDEWHITE_t1',
#  'CDLGRAVESTONEDOJI_t1',
#  'CDLHAMMER_t1',
#  'CDLHANGINGMAN_t1',
#  'CDLHARAMI_t1',
#  'CDLHARAMICROSS_t1',
#  'CDLHIGHWAVE_t1',
#  'CDLHIKKAKE_t1',
#  'CDLHIKKAKEMOD_t1',
#  'CDLHOMINGPIGEON_t1',
#  'CDLIDENTICAL3CROWS_t1',
#  'CDLINNECK_t1',
#  'CDLINVERTEDHAMMER_t1',
#  'CDLKICKING_t1',
#  'CDLKICKINGBYLENGTH_t1',
#  'CDLLADDERBOTTOM_t1',
#  'CDLLONGLEGGEDDOJI_t1',
#  'CDLLONGLINE_t1',
#  'CDLMARUBOZU_t1',
#  'CDLMATCHINGLOW_t1',
#  'CDLMATHOLD_t1',
#  'CDLMORNINGDOJISTAR_t1',
#  'CDLMORNINGSTAR_t1',
#  'CDLONNECK_t1',
#  'CDLPIERCING_t1',
#  'CDLRICKSHAWMAN_t1',
#  'CDLRISEFALL3METHODS_t1',
#  'CDLSEPARATINGLINES_t1',
#  'CDLSHOOTINGSTAR_t1',
#  'CDLSHORTLINE_t1',
#  'CDLSPINNINGTOP_t1',
#  'CDLSTALLEDPATTERN_t1',
#  'CDLSTICKSANDWICH_t1',
#  'CDLTAKURI_t1',
#  'CDLTASUKIGAP_t1',
#  'CDLTHRUSTING_t1',
#  'CDLTRISTAR_t1',
#  'CDLUNIQUE3RIVER_t1',
#  'CDLUPSIDEGAP2CROWS_t1',
#  'CDLXSIDEGAP3METHODS_t1',
#  'ATR_t2',
#  'RSI_t2',
#  'BB_upper_t2',
#  'BB_mid_t2',
#  'BB_lower_t2',
#  'SMA_10_t2',
#  'SMA_20_t2',
#  'EMA_10_t2',
#  'EMA_20_t2',
#  'MACD_t2',
#  'MACD_signal_t2',
#  'MACD_hist_t2',
#  'Supertrend_t2',
#  'CDL2CROWS_t2',
#  'CDL3BLACKCROWS_t2',
#  'CDL3INSIDE_t2',
#  'CDL3LINESTRIKE_t2',
#  'CDL3OUTSIDE_t2',
#  'CDL3STARSINSOUTH_t2',
#  'CDL3WHITESOLDIERS_t2',
#  'CDLABANDONEDBABY_t2',
#  'CDLADVANCEBLOCK_t2',
#  'CDLBELTHOLD_t2',
#  'CDLBREAKAWAY_t2',
#  'CDLCLOSINGMARUBOZU_t2',
#  'CDLCONCEALBABYSWALL_t2',
#  'CDLCOUNTERATTACK_t2',
#  'CDLDARKCLOUDCOVER_t2',
#  'CDLDOJI_t2',
#  'CDLDOJISTAR_t2',
#  'CDLDRAGONFLYDOJI_t2',
#  'CDLENGULFING_t2',
#  'CDLEVENINGDOJISTAR_t2',
#  'CDLEVENINGSTAR_t2',
#  'CDLGAPSIDESIDEWHITE_t2',
#  'CDLGRAVESTONEDOJI_t2',
#  'CDLHAMMER_t2',
#  'CDLHANGINGMAN_t2',
#  'CDLHARAMI_t2',
#  'CDLHARAMICROSS_t2',
#  'CDLHIGHWAVE_t2',
#  'CDLHIKKAKE_t2',
#  'CDLHIKKAKEMOD_t2',
#  'CDLHOMINGPIGEON_t2',
#  'CDLIDENTICAL3CROWS_t2',
#  'CDLINNECK_t2',
#  'CDLINVERTEDHAMMER_t2',
#  'CDLKICKING_t2',
#  'CDLKICKINGBYLENGTH_t2',
#  'CDLLADDERBOTTOM_t2',
#  'CDLLONGLEGGEDDOJI_t2',
#  'CDLLONGLINE_t2',
#  'CDLMARUBOZU_t2',
#  'CDLMATCHINGLOW_t2',
#  'CDLMATHOLD_t2',
#  'CDLMORNINGDOJISTAR_t2',
#  'CDLMORNINGSTAR_t2',
#  'CDLONNECK_t2',
#  'CDLPIERCING_t2',
#  'CDLRICKSHAWMAN_t2',
#  'CDLRISEFALL3METHODS_t2',
#  'CDLSEPARATINGLINES_t2',
#  'CDLSHOOTINGSTAR_t2',
#  'CDLSHORTLINE_t2',
#  'CDLSPINNINGTOP_t2',
#  'CDLSTALLEDPATTERN_t2',
#  'CDLSTICKSANDWICH_t2',
#  'CDLTAKURI_t2',
#  'CDLTASUKIGAP_t2',
#  'CDLTHRUSTING_t2',
#  'CDLTRISTAR_t2',
#  'CDLUNIQUE3RIVER_t2',
#  'CDLUPSIDEGAP2CROWS_t2',
#  'CDLXSIDEGAP3METHODS_t2',
#  'ATR_t3',
#  'RSI_t3',
#  'BB_upper_t3',
#  'BB_mid_t3',
#  'BB_lower_t3',
#  'SMA_10_t3',
#  'SMA_20_t3',
#  'EMA_10_t3',
#  'EMA_20_t3',
#  'MACD_t3',
#  'MACD_signal_t3',
#  'MACD_hist_t3',
#  'Supertrend_t3',
#  'CDL2CROWS_t3',
#  'CDL3BLACKCROWS_t3',
#  'CDL3INSIDE_t3',
#  'CDL3LINESTRIKE_t3',
#  'CDL3OUTSIDE_t3',
#  'CDL3STARSINSOUTH_t3',
#  'CDL3WHITESOLDIERS_t3',
#  'CDLABANDONEDBABY_t3',
#  'CDLADVANCEBLOCK_t3',
#  'CDLBELTHOLD_t3',
#  'CDLBREAKAWAY_t3',
#  'CDLCLOSINGMARUBOZU_t3',
#  'CDLCONCEALBABYSWALL_t3',
#  'CDLCOUNTERATTACK_t3',
#  'CDLDARKCLOUDCOVER_t3',
#  'CDLDOJI_t3',
#  'CDLDOJISTAR_t3',
#  'CDLDRAGONFLYDOJI_t3',
#  'CDLENGULFING_t3',
#  'CDLEVENINGDOJISTAR_t3',
#  'CDLEVENINGSTAR_t3',
#  'CDLGAPSIDESIDEWHITE_t3',
#  'CDLGRAVESTONEDOJI_t3',
#  'CDLHAMMER_t3',
#  'CDLHANGINGMAN_t3',
#  'CDLHARAMI_t3',
#  'CDLHARAMICROSS_t3',
#  'CDLHIGHWAVE_t3',
#  'CDLHIKKAKE_t3',
#  'CDLHIKKAKEMOD_t3',
#  'CDLHOMINGPIGEON_t3',
#  'CDLIDENTICAL3CROWS_t3',
#  'CDLINNECK_t3',
#  'CDLINVERTEDHAMMER_t3',
#  'CDLKICKING_t3',
#  'CDLKICKINGBYLENGTH_t3',
#  'CDLLADDERBOTTOM_t3',
#  'CDLLONGLEGGEDDOJI_t3',
#  'CDLLONGLINE_t3',
#  'CDLMARUBOZU_t3',
#  'CDLMATCHINGLOW_t3',
#  'CDLMATHOLD_t3',
#  'CDLMORNINGDOJISTAR_t3',
#  'CDLMORNINGSTAR_t3',
#  'CDLONNECK_t3',
#  'CDLPIERCING_t3',
#  'CDLRICKSHAWMAN_t3',
#  'CDLRISEFALL3METHODS_t3',
#  'CDLSEPARATINGLINES_t3',
#  'CDLSHOOTINGSTAR_t3',
#  'CDLSHORTLINE_t3',
#  'CDLSPINNINGTOP_t3',
#  'CDLSTALLEDPATTERN_t3',
#  'CDLSTICKSANDWICH_t3',
#  'CDLTAKURI_t3',
#  'CDLTASUKIGAP_t3',
#  'CDLTHRUSTING_t3',
#  'CDLTRISTAR_t3',
#  'CDLUNIQUE3RIVER_t3',
#  'CDLUPSIDEGAP2CROWS_t3',
#  'CDLXSIDEGAP3METHODS_t3',
#  'ATR_t4',
#  'RSI_t4',
#  'BB_upper_t4',
#  'BB_mid_t4',
#  'BB_lower_t4',
#  'SMA_10_t4',
#  'SMA_20_t4',
#  'EMA_10_t4',
#  'EMA_20_t4',
#  'MACD_t4',
#  'MACD_signal_t4',
#  'MACD_hist_t4',
#  'Supertrend_t4',
#  'CDL2CROWS_t4',
#  'CDL3BLACKCROWS_t4',
#  'CDL3INSIDE_t4',
#  'CDL3LINESTRIKE_t4',
#  'CDL3OUTSIDE_t4',
#  'CDL3STARSINSOUTH_t4',
#  'CDL3WHITESOLDIERS_t4',
#  'CDLABANDONEDBABY_t4',
#  'CDLADVANCEBLOCK_t4',
#  'CDLBELTHOLD_t4',
#  'CDLBREAKAWAY_t4',
#  'CDLCLOSINGMARUBOZU_t4',
#  'CDLCONCEALBABYSWALL_t4',
#  'CDLCOUNTERATTACK_t4',
#  'CDLDARKCLOUDCOVER_t4',
#  'CDLDOJI_t4',
#  'CDLDOJISTAR_t4',
#  'CDLDRAGONFLYDOJI_t4',
#  'CDLENGULFING_t4',
#  'CDLEVENINGDOJISTAR_t4',
#  'CDLEVENINGSTAR_t4',
#  'CDLGAPSIDESIDEWHITE_t4',
#  'CDLGRAVESTONEDOJI_t4',
#  'CDLHAMMER_t4',
#  'CDLHANGINGMAN_t4',
#  'CDLHARAMI_t4',
#  'CDLHARAMICROSS_t4',
#  'CDLHIGHWAVE_t4',
#  'CDLHIKKAKE_t4',
#  'CDLHIKKAKEMOD_t4',
#  'CDLHOMINGPIGEON_t4',
#  'CDLIDENTICAL3CROWS_t4',
#  'CDLINNECK_t4',
#  'CDLINVERTEDHAMMER_t4',
#  'CDLKICKING_t4',
#  'CDLKICKINGBYLENGTH_t4',
#  'CDLLADDERBOTTOM_t4',
#  'CDLLONGLEGGEDDOJI_t4',
#  'CDLLONGLINE_t4',
#  'CDLMARUBOZU_t4',
#  'CDLMATCHINGLOW_t4',
#  'CDLMATHOLD_t4',
#  'CDLMORNINGDOJISTAR_t4',
#  'CDLMORNINGSTAR_t4',
#  'CDLONNECK_t4',
#  'CDLPIERCING_t4',
#  'CDLRICKSHAWMAN_t4',
#  'CDLRISEFALL3METHODS_t4',
#  'CDLSEPARATINGLINES_t4',
#  'CDLSHOOTINGSTAR_t4',
#  'CDLSHORTLINE_t4',
#  'CDLSPINNINGTOP_t4',
#  'CDLSTALLEDPATTERN_t4',
#  'CDLSTICKSANDWICH_t4',
#  'CDLTAKURI_t4',
#  'CDLTASUKIGAP_t4',
#  'CDLTHRUSTING_t4',
#  'CDLTRISTAR_t4',
#  'CDLUNIQUE3RIVER_t4',
#  'CDLUPSIDEGAP2CROWS_t4',
#  'CDLXSIDEGAP3METHODS_t4',
#  'ATR_t5',
#  'RSI_t5',
#  'BB_upper_t5',
#  'BB_mid_t5',
#  'BB_lower_t5',
#  'SMA_10_t5',
#  'SMA_20_t5',
#  'EMA_10_t5',
#  'EMA_20_t5',
#  'MACD_t5',
#  'MACD_signal_t5',
#  'MACD_hist_t5',
#  'Supertrend_t5',
#  'CDL2CROWS_t5',
#  'CDL3BLACKCROWS_t5',
#  'CDL3INSIDE_t5',
#  'CDL3LINESTRIKE_t5',
#  'CDL3OUTSIDE_t5',
#  'CDL3STARSINSOUTH_t5',
#  'CDL3WHITESOLDIERS_t5',
#  'CDLABANDONEDBABY_t5',
#  'CDLADVANCEBLOCK_t5',
#  'CDLBELTHOLD_t5',
#  'CDLBREAKAWAY_t5',
#  'CDLCLOSINGMARUBOZU_t5',
#  'CDLCONCEALBABYSWALL_t5',
#  'CDLCOUNTERATTACK_t5',
#  'CDLDARKCLOUDCOVER_t5',
#  'CDLDOJI_t5',
#  'CDLDOJISTAR_t5',
#  'CDLDRAGONFLYDOJI_t5',
#  'CDLENGULFING_t5',
#  'CDLEVENINGDOJISTAR_t5',
#  'CDLEVENINGSTAR_t5',
#  'CDLGAPSIDESIDEWHITE_t5',
#  'CDLGRAVESTONEDOJI_t5',
#  'CDLHAMMER_t5',
#  'CDLHANGINGMAN_t5',
#  'CDLHARAMI_t5',
#  'CDLHARAMICROSS_t5',
#  'CDLHIGHWAVE_t5',
#  'CDLHIKKAKE_t5',
#  'CDLHIKKAKEMOD_t5',
#  'CDLHOMINGPIGEON_t5',
#  'CDLIDENTICAL3CROWS_t5',
#  'CDLINNECK_t5',
#  'CDLINVERTEDHAMMER_t5',
#  'CDLKICKING_t5',
#  'CDLKICKINGBYLENGTH_t5',
#  'CDLLADDERBOTTOM_t5',
#  'CDLLONGLEGGEDDOJI_t5',
#  'CDLLONGLINE_t5',
#  'CDLMARUBOZU_t5',
#  'CDLMATCHINGLOW_t5',
#  'CDLMATHOLD_t5',
#  'CDLMORNINGDOJISTAR_t5',
#  'CDLMORNINGSTAR_t5',
#  'CDLONNECK_t5',
#  'CDLPIERCING_t5',
#  'CDLRICKSHAWMAN_t5',
#  'CDLRISEFALL3METHODS_t5',
#  'CDLSEPARATINGLINES_t5',
#  'CDLSHOOTINGSTAR_t5',
#  'CDLSHORTLINE_t5',
#  'CDLSPINNINGTOP_t5',
#  'CDLSTALLEDPATTERN_t5',
#  'CDLSTICKSANDWICH_t5',
#  'CDLTAKURI_t5',
#  'CDLTASUKIGAP_t5',
#  'CDLTHRUSTING_t5',
#  'CDLTRISTAR_t5',
#  'CDLUNIQUE3RIVER_t5',
#  'CDLUPSIDEGAP2CROWS_t5',
#  'CDLXSIDEGAP3METHODS_t5',
#  'TP_theoretical',
#  'SL_theoretical',
#  'offset',
#  'future_idx',
#  'target_idx',
#  'target_close',
#  'target']

# %%
# 2. Encoding target
label_map = {-1: 0, 0: 1, 1: 2}
df['y'] = df['target'].map(label_map)
df
# Out:
#       base_idx     Open     High      Low    Close  Volume  \
# 330         33  1.32174  1.32191  1.32172  1.32177       0
# 331         33  1.32174  1.32191  1.32172  1.32177       0
# 332         33  1.32174  1.32191  1.32172  1.32177       0
# 333         33  1.32174  1.32191  1.32172  1.32177       0
# 334         33  1.32174  1.32191  1.32172  1.32177       0
# ...        ...      ...      ...      ...      ...     ...
# 9880       990  1.32431  1.32467  1.32427  1.32465       0
# 9881       990  1.32431  1.32467  1.32427  1.32465       0
# 9882       991  1.32466  1.32485  1.32466  1.32484       0
# 9883       991  1.32466  1.32485  1.32466  1.32484       0
# 9884       992  1.32486  1.32504  1.32468  1.32473       0
#
#                 datetime  Close_t1  Close_t2  Close_t3  ...  \
# 330  2013-01-01 17:38:00   1.32175   1.32128   1.32091  ...
# 331  2013-01-01 17:38:00   1.32175   1.32128   1.32091  ...
# 332  2013-01-01 17:38:00   1.32175   1.32128   1.32091  ...
# 333  2013-01-01 17:38:00   1.32175   1.32128   1.32091  ...
# 334  2013-01-01 17:38:00   1.32175   1.32128   1.32091  ...
# ...                  ...       ...       ...       ...  ...
# 9880 2013-01-02 09:35:00   1.32430   1.32439   1.32444  ...
# 9881 2013-01-02 09:35:00   1.32430   1.32439   1.32444  ...
# 9882 2013-01-02 09:36:00   1.32465   1.32430   1.32439  ...
# 9883 2013-01-02 09:36:00   1.32465   1.32430   1.32439  ...
# 9884 2013-01-02 09:37:00   1.32484   1.32465   1.32430  ...
#
#       CDLUPSIDEGAP2CROWS_t5  CDLXSIDEGAP3METHODS_t5  TP_theoretical  \
# 330                       0                       0        1.322244
# 331                       0                       0        1.322244
# 332                       0                       0        1.322244
# 333                       0                       0        1.322244
# 334                       0                       0        1.322244
# ...                     ...                     ...             ...
# 9880                      0                       0        1.325225
# 9881                      0                       0        1.325225
# 9882                      0                       0        1.325403
# 9883                      0                       0        1.325403
# 9884                      0                       0        1.325304
#
#       SL_theoretical  offset  future_idx  target_idx  target_close  target  y
# 330         1.321533       1          34          35       1.32175       0  1
# 331         1.321533       2          35          36       1.32177       0  1
# 332         1.321533       3          36          37       1.32164       0  1
# 333         1.321533       4          37          38       1.32167       0  1
# 334         1.321533       5          38          39       1.32160       0  1
# ...              ...     ...         ...         ...           ...     ... ..
# 9880        1.324362       2         992         993       1.32468       0  1
# 9881        1.324362       3         993         994       1.32520       0  1
# 9882        1.324559       1         992         993       1.32468       0  1
# 9883        1.324559       2         993         994       1.32520       0  1
# 9884        1.324443       1         993         994       1.32520       0  1
#
# [9555 rows x 474 columns]

# %%
# 3. Bilanciamento con undersampling
df_0 = df[df['y'] == 0]
df_1 = df[df['y'] == 1]
df_2 = df[df['y'] == 2]
n_min = min(len(df_0), len(df_2))
df_1_under = resample(df_1, replace=False, n_samples=n_min, random_state=42)
df_balanced = pd.concat([df_0, df_1_under, df_2], ignore_index=True)
print(f"Bilanciato: {df_balanced['y'].value_counts().to_dict()}")
# Out:
# Bilanciato: {0: 2519, 1: 1469, 2: 1469}

# %%
# 4. Feature selection iniziale
exclude_cols = [col for col in ['datetime', 'row_nr', 'offset', 'target', 'y'] if col in df_balanced.columns]
X_full = df_balanced.drop(columns=exclude_cols)
y = df_balanced['y']
X_full = X_full.astype(np.float32)

# %%
# 5. Primo training per importance
X_sample, _, y_sample, _ = train_test_split(X_full, y, train_size=2000, stratify=y, random_state=42)
model_temp = XGBClassifier(
    objective='multi:softprob',
    num_class=3,
    eval_metric='mlogloss',
    tree_method='hist',
    n_estimators=100,
    max_depth=4,
    learning_rate=0.1,
    subsample=0.7,
    colsample_bytree=0.7,
    random_state=42,
    n_jobs=-1
)
model_temp.fit(X_sample, y_sample)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/IPython/core/formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/IPython/core/formatters.py?line=970'>971</a>     method = get_real_method(obj, self.print_method)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/IPython/core/formatters.py?line=972'>973</a>     if method is not None:
# --> <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/IPython/core/formatters.py?line=973'>974</a>         return method(include=include, exclude=exclude)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/IPython/core/formatters.py?line=974'>975</a>     return None
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/IPython/core/formatters.py?line=975'>976</a> else:
#
# File /opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py:469, in BaseEstimator._repr_mimebundle_(self, **kwargs)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=466'>467</a> output = {"text/plain": repr(self)}
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=467'>468</a> if get_config()["display"] == "diagram":
# --> <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=468'>469</a>     output["text/html"] = estimator_html_repr(self)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=469'>470</a> return output
#
# File /opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_estimator_html_repr.py:387, in estimator_html_repr(estimator)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_estimator_html_repr.py?line=384'>385</a> else:
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_estimator_html_repr.py?line=385'>386</a>     try:
# --> <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_estimator_html_repr.py?line=386'>387</a>         check_is_fitted(estimator)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_estimator_html_repr.py?line=387'>388</a>         status_label = "<span>Fitted</span>"
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_estimator_html_repr.py?line=388'>389</a>         is_fitted_css_class = "fitted"
#
# File /opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/validation.py:1751, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/validation.py?line=1747'>1748</a> if not hasattr(estimator, "fit"):
#    <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/validation.py?line=1748'>1749</a>     raise TypeError("%s is not an estimator instance." % (estimator))
# -> <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/validation.py?line=1750'>1751</a> tags = get_tags(estimator)
#    <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/validation.py?line=1752'>1753</a> if not tags.requires_fit and attributes is None:
#    <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/validation.py?line=1753'>1754</a>     return
#
# File /opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_tags.py:430, in get_tags(estimator)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_tags.py?line=427'>428</a> for klass in reversed(type(estimator).mro()):
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_tags.py?line=428'>429</a>     if "__sklearn_tags__" in vars(klass):
# --> <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_tags.py?line=429'>430</a>         sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_tags.py?line=430'>431</a>         class_order.append(klass)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_tags.py?line=431'>432</a>     elif "_more_tags" in vars(klass):
#
# File /opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py:540, in ClassifierMixin.__sklearn_tags__(self)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=538'>539</a> def __sklearn_tags__(self):
# --> <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=539'>540</a>     tags = super().__sklearn_tags__()
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=540'>541</a>     tags.estimator_type = "classifier"
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=541'>542</a>     tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/IPython/core/formatters.py?line=341'>342</a>     method = get_real_method(obj, self.print_method)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/IPython/core/formatters.py?line=342'>343</a>     if method is not None:
# --> <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/IPython/core/formatters.py?line=343'>344</a>         return method()
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/IPython/core/formatters.py?line=344'>345</a>     return None
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/IPython/core/formatters.py?line=345'>346</a> else:
#
# File /opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py:463, in BaseEstimator._repr_html_inner(self)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=457'>458</a> def _repr_html_inner(self):
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=458'>459</a>     """This function is returned by the @property `_repr_html_` to make
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=459'>460</a>     `hasattr(estimator, "_repr_html_") return `True` or `False` depending
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=460'>461</a>     on `get_config()["display"]`.
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=461'>462</a>     """
# --> <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=462'>463</a>     return estimator_html_repr(self)
#
# File /opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_estimator_html_repr.py:387, in estimator_html_repr(estimator)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_estimator_html_repr.py?line=384'>385</a> else:
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_estimator_html_repr.py?line=385'>386</a>     try:
# --> <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_estimator_html_repr.py?line=386'>387</a>         check_is_fitted(estimator)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_estimator_html_repr.py?line=387'>388</a>         status_label = "<span>Fitted</span>"
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_estimator_html_repr.py?line=388'>389</a>         is_fitted_css_class = "fitted"
#
# File /opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/validation.py:1751, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/validation.py?line=1747'>1748</a> if not hasattr(estimator, "fit"):
#    <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/validation.py?line=1748'>1749</a>     raise TypeError("%s is not an estimator instance." % (estimator))
# -> <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/validation.py?line=1750'>1751</a> tags = get_tags(estimator)
#    <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/validation.py?line=1752'>1753</a> if not tags.requires_fit and attributes is None:
#    <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/validation.py?line=1753'>1754</a>     return
#
# File /opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_tags.py:430, in get_tags(estimator)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_tags.py?line=427'>428</a> for klass in reversed(type(estimator).mro()):
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_tags.py?line=428'>429</a>     if "__sklearn_tags__" in vars(klass):
# --> <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_tags.py?line=429'>430</a>         sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_tags.py?line=430'>431</a>         class_order.append(klass)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/utils/_tags.py?line=431'>432</a>     elif "_more_tags" in vars(klass):
#
# File /opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py:540, in ClassifierMixin.__sklearn_tags__(self)
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=538'>539</a> def __sklearn_tags__(self):
# --> <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=539'>540</a>     tags = super().__sklearn_tags__()
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=540'>541</a>     tags.estimator_type = "classifier"
#     <a href='file:///opt/anaconda3/envs/ragabot/lib/python3.12/site-packages/sklearn/base.py?line=541'>542</a>     tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=-1, num_class=3, num_parallel_tree=None, ...)

# %%
importances = model_temp.feature_importances_
important_features = X_full.columns[importances > 0.0025]
print(f"Feature selezionate: {len(important_features)} su {X_full.shape[1]}")
pd.Series(important_features).to_csv("selected_features.csv", index=False)
# Out:
# Feature selezionate: 135 su 470

# %%
X = X_full[important_features]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# 6. Optuna tuning
def objective(trial):
    params = {
        'objective': 'multi:softprob',
        'num_class': 3,
        'eval_metric': 'mlogloss',
        'tree_method': 'hist',
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'max_depth': trial.suggest_int('max_depth', 3, 7),
        'n_estimators': trial.suggest_int('n_estimators', 100, 400),
        'subsample': trial.suggest_float('subsample', 0.6, 0.95),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 0.95),
        'random_state': 42,
        'n_jobs': -1
    }
    model = XGBClassifier(**params)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return f1_score(y_test, y_pred, average='macro')

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=25)
print("Best trial:", study.best_trial.params)

# 7. Train finale con best params
final_model = XGBClassifier(
    **study.best_trial.params,
    objective='multi:softprob',
    num_class=3,
    eval_metric='mlogloss',
    tree_method='hist',
    random_state=42,
    n_jobs=-1
)
final_model.fit(X_train, y_train)

# 8. Probabilità e threshold
probs = final_model.predict_proba(X_test)

def get_best_f1_threshold(y_true, y_prob):
    precision, recall, thresholds = precision_recall_curve(y_true.astype(int), y_prob)
    f1 = 2 * precision * recall / (precision + recall + 1e-9)
    best_idx = np.argmax(f1[:-1])
    return thresholds[best_idx], precision[best_idx], recall[best_idx], f1[best_idx]

best_thresh_0, *_ = get_best_f1_threshold(y_test == 0, probs[:, 0])
best_thresh_2, *_ = get_best_f1_threshold(y_test == 2, probs[:, 2])

y_pred_opt = np.where(probs[:, 0] >= best_thresh_0, 0,
                      np.where(probs[:, 2] >= best_thresh_2, 2, 1))
inv_map = {0: -1, 1: 0, 2: 1}
y_test_labels = y_test.map(inv_map)
y_pred_labels = pd.Series(y_pred_opt).map(inv_map)

print("\n=== REPORT THRESHOLD OTTIMALI ===")
print(confusion_matrix(y_test_labels, y_pred_labels, labels=[-1, 0, 1]))
print(classification_report(y_test_labels, y_pred_labels, target_names=["SL_hit", "No_hit", "TP_hit"]))

# %%
# 9. Salva modello finale
joblib.dump({
    'model': final_model,
    'thresh_sl_opt': best_thresh_0,
    'thresh_tp_opt': best_thresh_2,
    'selected_features': list(important_features),
    'best_params': study.best_trial.params
}, 'xgb_tp_sl_model_thresh.joblib')

print("Modello, threshold e feature salvati in xgb_tp_sl_model_thresh.joblib e selected_features.csv")
